# %% [markdown]
# # **Violência no Rio de Janeiro**
#
# ![Rio de Janeiro - Capa.jpg](data:image/jpeg;base64,...)
#
# Assim como anos atrás, hoje o tema violência ainda é um óbice a ser estudado e que desconforta a vida de todos os cidadãos brasileiros. Com foco no Estado do Rio de Janeiro, um dos estados com mais ações violentas por conta do tráfico e contrabando de armas, neste projeto iremos análisar dados fornecidos pelo **ISPDados** - o Instituto de Segurança Pública do Rio de Janeiro com o objetivo de análisar os tipos de violência.
#
# Com a finalidade de disseminar o conhecimento, segue o link da extração dos dados: http://www.ispdados.rj.gov.br/estatistica.html. Inicialmente vamos importar o pacote *pandas* e a base de dados da Polícia Militar do Rio de Janeiro.

# %%
# importar o pandas
import pandas as pd

# %% [markdown]
# # **Analisando os Dados do Rio de Janeiro**
#
# Alvo nos noticiários, a violência no Rio de Janeiro, assim como em todos os lugares do país, tem raiz na miséria, no descaso público em relação ao atendimento das necessidades básicas dos cidadãos, na falta de emprego e educação, direitos básicos que são garantidos por lei.
#
# No entanto, a realidade é bem mais cruel, revela condições extremas de vida e violência exacerbada diante da inexistência de outro caminho.

# %% [markdown]
# # **Obtenção dos Dados**
#
# Os dados que serão analisados foram retirados do site do [ISPDados](https://http://www.ispdados.rj.gov.br/estatistica.html). Neste *dataset* vamos analisar os casos de violência com maior incidência. Não deixe de acompanhar!

# %% [markdown]
# # **Importando os Dados**
#
# Nesta seção iremos importar os dados do *dataset*.

# %%
# importando o dataset
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/violencia_rio.csv")

# %% [markdown]
# # **Análise Inicial dos Dados**
#
# Analisar dados pode aparentar uma tarefa difícil, pois envolve linguagem de programação, códigos e lógica, mas análisar é mais do que isso, é retirar dos dados uma narrativa, uma informação valiosa, é interpretar o que se vê em números.
#
# Então, inicialmente iremos fazer a análise do *dataset*.

# %%
# verificar o tamanho do DataFrame
df.shape
# Out:
# (344, 56)

# %% [markdown]
# No DataFrame verificamos que existem 344 linhas e 56 colunas recheadas de informações. Agora iremos veridicar os nomes das colunas e os tipos de variáveis, no caso se são *int*, *float* ou "object*.

# %%
# extrair e imprimir o nome das colunas
df.columns
# Out:
# Index(['vano', 'mes', 'hom_doloso', 'lesao_corp_morte', 'latrocinio',
#        'hom_por_interv_policial', 'tentat_hom', 'lesao_corp_dolosa', 'estupro',
#        'hom_culposo', 'lesao_corp_culposa', 'roubo_comercio',
#        'roubo_residencia', 'roubo_veiculo', 'roubo_carga', 'roubo_transeunte',
#        'roubo_em_coletivo', 'roubo_banco', 'roubo_cx_eletronico',
#        'roubo_celular', 'roubo_conducao_saque', 'roubo_apos_saque',
#        'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos',
#        'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
#        'recuperacao_veiculos', 'apf', 'aaapai', 'cmp', 'cmba', 'ameaca',
#        'pessoas_desaparecidas', 'encontro_cadaver', 'encontro_ossada',
# ...

# %%
# verificar os tipos das variáveis 
df.dtypes
# Out:
# vano                            int64
# mes                             int64
# hom_doloso                      int64
# lesao_corp_morte              float64
# latrocinio                      int64
# hom_por_interv_policial       float64
# tentat_hom                      int64
# lesao_corp_dolosa               int64
# estupro                       float64
# hom_culposo                   float64
# lesao_corp_culposa            float64
# roubo_comercio                  int64
# roubo_residencia                int64
# roubo_veiculo                   int64
# roubo_carga                     int64
# roubo_transeunte                int64
# roubo_em_coletivo               int64
# roubo_banco                     int64
# roubo_cx_eletronico           float64
# roubo_celular                 float64
# roubo_conducao_saque          float64
# roubo_apos_saque              float64
# roubo_bicicleta               float64
# outros_roubos                   int64
# total_roubos                    int64
# ...

# %% [markdown]
# É interessante notar que com as funções *shape* e *dtype*  você consegue visualizar o nome das colunas, denominadas de variáveis e também o tipo delas. No código acima dá para verificar que a maioria das variáveis são do tipo *int* (números inteiros) e *float* (números com casas decimais).
#
# Agora iremos analisar as 5 primeiras entradas e a porcentagem de valores nulos, ou seja, a porcentagem de outliers.
#
# Os *outliers* são valores nulos, ou seja, que não apresentam valor algum dentro do dataset, e isso acontece por dois motivos: a inexistência de dados ou então o mal preenchimento das informações.
#
# Como podemos perceber os dados começam a ser contabilizados no ano de 1991, ano em que a tecnologia estava ganhando força e a cultura dos dados era um tema que não transitava com frequência na mente poderosa dos cientistas.

# %%
# visualizar as 5 primeiras entradas
df.head()
# Out:
#    vano  mes  hom_doloso  ...  indicador_roubo_veic  registro_ocorrencias  fase
# 0  1991    1         657  ...                  1174                   NaN     3
# 1  1991    2         732  ...                  1097                   NaN     3
# 2  1991    3         713  ...                  1265                   NaN     3
# 3  1991    4         634  ...                  1415                   NaN     3
# 4  1991    5         650  ...                  1449                   NaN     3
#
# [5 rows x 56 columns]

# %%
# verificar a porcentagem de outliers 
(df.isnull().sum()/ df.shape[0]).sort_values(ascending=False)
# Out:
# roubo_bicicleta               0.802326
# furto_bicicleta               0.802326
# apreensao_drogas_sem_autor    0.523256
# posse_drogas                  0.523256
# apf                           0.523256
# aaapai                        0.523256
# cmp                           0.523256
# trafico_drogas                0.523256
# cmba                          0.523256
# sequestro_relampago           0.418605
# furto_coletivo                0.418605
# extorsao                      0.418605
# furto_celular                 0.418605
# roubo_apos_saque              0.418605
# roubo_conducao_saque          0.418605
# roubo_cx_eletronico           0.418605
# estupro                       0.418605
# estelionato                   0.418605
# pol_civis_mortos_serv         0.418605
# pol_militares_mortos_serv     0.418605
# pessoas_desaparecidas         0.383721
# encontro_ossada               0.383721
# roubo_celular                 0.313953
# lesao_corp_culposa            0.279070
# ...

# %% [markdown]
# Acima, podemos ver que algumas das variáveis tem valores nulos em proporções consideráveis como é o exemplo de crimes relacionados a furtos, roubos, lesões, homicídios e apreensão de drogas.
#
# Existem outras formas de analisarmos e explorarmos dados, como por exemplo:
#
# *   Números anuais por crime
# *   Números mensais por crime
# *   Categorias de crimes (contra a vida, contra o patrimônio e etc.)

# %% [markdown]
# # **Informações Estatísticas da Violência no Rio de Janeiro**
#
# Neste tópico vamos analisar estatísticamente as informações do DataFrame utilizando a função *describe*, a qual fornece os seguintes insights:
#
# *   Identificar outliers
# *   Entender melhor a distribuição dos dados
# *   Identificar falhas na distribuição dos dados.
# *   Após a limpeza dos dados, verificar a eficácia e as diferenças entre os dados tratados e não tratados.

# %%
# imprimir o resumo do DataFrame
df.describe()
# Out:
#               vano         mes  ...  registro_ocorrencias        fase
# count   344.000000  344.000000  ...            248.000000  344.000000
# mean   2004.837209    6.453488  ...          53794.161290    2.994186
# std       8.289036    3.447759  ...          11039.051992    0.076138
# min    1991.000000    1.000000  ...          30621.000000    2.000000
# 25%    1998.000000    3.000000  ...          45374.500000    3.000000
# 50%    2005.000000    6.000000  ...          54926.500000    3.000000
# 75%    2012.000000    9.000000  ...          63292.500000    3.000000
# max    2019.000000   12.000000  ...          75403.000000    3.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# Acima conseguimos identidicar o número de vezes que a variável aparece dentro do DataFrame, bem como a média, o desvio padrão, o mínimo e a máxima, além de verificar a porcentagem dos valores em 25%, 50% e 75%.

# %% [markdown]
# # **Crimes contra o Patrimônio**
#
# Esta seção será dedicada a análise dos crimes contra o patrimônio, ou seja, crimes de roubo, furto e recuperação de veículos.
#
# Os crimes contra o patrimônio são aqueles que afetam os bens da vítima, sendo que a lei penal protege justamente os objetos da pessoa lesada. Entretanto, veremos a média com que esses crimes acontecem para analisar se realmente o bem é protegido.

# %%
# ver a média da variável roubo_veiculo
mean_roubo_veiculo = df.roubo_veiculo.mean()
print(mean_roubo_veiculo)
# Out:
# 2448.6976744186045

# %% [markdown]
# Assim, verificamos que a média de roubo de veículos é de 2448.7 veículos por mês.

# %%
# ver a média da variável furto_veiculos
mean_furto_veiculos = df.furto_veiculos.mean()
print(mean_furto_veiculos)
# Out:
# 1674.671511627907

# %% [markdown]
# Em relação à média de furto de veículos, observa-se que em comparação com os roubos a média é 1674.67, ou seja, furtos que à princípio não envolvem grave ameaça e violência a incidência é baixa.

# %%
mean_recuperacao_veiculos = df.recuperacao_veiculos.mean()
print(mean_recuperacao_veiculos)
# Out:
# 1772.2383720930231

# %% [markdown]
# Já a média de veículos recuperados é de 1772.23.
#
# Vamos então analisar a porcentagem de carros recuperados em relação aos carros roubados e os furtados, além de encontrar os valores máximos e mínimos de homicídios dolosos.

# %%
# ver a média da variável recuperacao_veiculos
mean_recuperacao_veiculos = df.recuperacao_veiculos.mean()

# total de veículos perdidos
total = mean_recuperacao_veiculos + mean_furto_veiculos
print('Média de Veículos Perdidos por Mês: {:.2f}'.format(total))
print('Veículos Recuperados por Mês: {:.2f}'.format(mean_recuperacao_veiculos))

# porcentagem de veículos recuperados
pct = mean_recuperacao_veiculos/total*100

print('{:.2f}% dos veículos roubados ou furtados são recuperados.'.format(pct))
# Out:
# Média de Veículos Perdidos por Mês: 3446.91
# Veículos Recuperados por Mês: 1772.24
# 51.42% dos veículos roubados ou furtados são recuperados.

# %% [markdown]
# Ao verificar a média de veículos em recuperação sobre os roubados e furtados, temos que 3.446.91 veículos são perdidos, ou seja, a polícia deixa de resgatar mais da metade dos veículos, 51.42%, tendo em vista a violência na cidade.

# %% [markdown]
# # **Crimes contra a Vida**
#
# Abaixo vamos identificar o máximo e mínimo registrado para a variável hom_doloso ao longo do período.

# %%
# valores máximo e mínimo de hom_doloso
max_hom_doloso = df.hom_doloso.max()
min_hom_doloso = df.hom_doloso.min()

# imprimir os valores máximos e mínimos
print("Min:\t{}".format(min_hom_doloso))
print("Max:\t{}".format(max_hom_doloso))
# Out:
# Min:	272
# Max:	831

# %% [markdown]
# Aqui notamos que no mês com menor número de casos foram registrados 272 homicídios dolosos em comparação com o mês com número mais elevado que foi de 831 homídios.
#
# Com a análise do máximo e mínimo verificamos qual a quantidade de casos, ou seja, de ocorrências de qualquer variável. Nesse sentido, vamos investigar mais a fundo as entradas deste *dataset*.

# %%
# verificando o mês com menor número de homicídios dolosos
df[df.hom_doloso == 272]
# Out:
#      vano  mes  hom_doloso  ...  indicador_roubo_veic  registro_ocorrencias  fase
# 293  2015    6         272  ...                  2254               60357.0     3
#
# [1 rows x 56 columns]

# %%
# verificando o mês com maior número de homicídios dolosos
df[df.hom_doloso == 831]
# Out:
#     vano  mes  hom_doloso  ...  indicador_roubo_veic  registro_ocorrencias  fase
# 48  1995    1         831  ...                  2060                   NaN     3
#
# [1 rows x 56 columns]

# %% [markdown]
# Acima, ao analisarmos os dados verificamos que o ano de maior incidência de homicídios dolosos foi em 1995 e o de menor foi em 2015. Assim, pode-se até concluir que os casos de homicídios dolosos vem diminuindo de ano em ano.
#
# Todavia, apenas uma análise mais aprofundada para predizer com mais certeza.

# %% [markdown]
# # **Visualização de Dados**
#
# Agora iremos observar os dados através de visualizações gráficas que facilitaram a compreensão das informações contidas no *dataset*.

# %% [markdown]
# Histogramas são poderosas ferramentas de visualização que nos auxiliam a entendet a dristribuição dos valores em variáveis.
#
# Abaixo faremos a análise em relação à variável hom_doloso.

# %%
# plotar histograma de hom_doloso
df.hom_doloso.hist();

# %% [markdown]
# No gráfico acima observamos o seguinte:
#
#
# *   70 meses com valores de 500 a 550 homicídios dolosos registrados ao longo do período
# *   Menos de 10 meses houveram 800 casos de homicídio dolosos registrados ao longo do período

# %% [markdown]
# Por fim, vamos analisar a variável roubo_em_coletivo utilizando gráfico de linha.

# %%
# plotar gráfico de linhas para roubo_em_coletivo
df.roubo_em_coletivo.plot();

# %% [markdown]
# # **Conclusão**
#
# A lição apresentada nesta análise é a de compreender os dados, os interpretando e se atentando aos detalhes de cada *dataset*, já que as informações subtraídas destas análises são sobre a violência na cidade do Rio de Janeiro.
#
# Entretanto, além dos dados, a narrativa, a forma como se interpreta e se faz o repasse dessa informação também é importante, já que quanto mais pessoas entendem, mais acadêmicos, cientistas, analistas e profissionais serão alcançados.
#
# Então, assim como a aquisição, o tratamento e a exploração dos dados são etapas necessárias, a narrativa também passa a se tornar. E hoje com a preocupação direcionada à comunicação, quem der atenção a esse requisito sairá na frente de muitos!
